# %% [markdown]
# # Jupyter Data Science Workflow
#
# ### From exploratory analysis to reproducible science
#
# *Jonathan Chiu*

# %%
URL = "https://data.seattle.gov/api/views/65db-xm6k/rows.csv?accessType=DOWNLOAD"

# %%
from urllib.request import urlretrieve
urlretrieve(URL, 'Fremont.csv')
# Out:
# ('Fremont.csv', <http.client.HTTPMessage at 0x6677090>)

# %%
# !head Fremont.csv
# Out:
# Date,Fremont Bridge West Sidewalk,Fremont Bridge East Sidewalk
# 10/03/2012 12:00:00 AM,4,9
# 10/03/2012 01:00:00 AM,4,6
# 10/03/2012 02:00:00 AM,1,1
# 10/03/2012 03:00:00 AM,2,3
# 10/03/2012 04:00:00 AM,6,1
# 10/03/2012 05:00:00 AM,21,10
# 10/03/2012 06:00:00 AM,105,50
# 10/03/2012 07:00:00 AM,257,95
# 10/03/2012 08:00:00 AM,291,146

# %%
import pandas as pd
data = pd.read_csv('Fremont.csv', index_col='Date', parse_dates=True)
data.head()
# Out:
#                      Fremont Bridge West Sidewalk  \
# Date
# 2012-10-03 00:00:00                           4.0
# 2012-10-03 01:00:00                           4.0
# 2012-10-03 02:00:00                           1.0
# 2012-10-03 03:00:00                           2.0
# 2012-10-03 04:00:00                           6.0
#
#                      Fremont Bridge East Sidewalk
# Date
# 2012-10-03 00:00:00                           9.0
# 2012-10-03 01:00:00                           6.0
# 2012-10-03 02:00:00                           1.0
# 2012-10-03 03:00:00                           3.0
# 2012-10-03 04:00:00                           1.0

# %%
# %matplotlib inline
data.resample('W').sum().plot();    # data.plot() had too many data points for the dataset to plot so resampling it into Weeks

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn')

data.columns = ['West', 'East']

data.resample('W').sum().plot();

# %%
# looking at annual trend
data['Total'] = data['West'] + data['East']

ax = data.resample('D').sum().rolling(365).sum().plot();
ax.set_ylim(0, None) # to get better overview to see how much it actually changed
# Out:
# (0, 1136322.15)

# %%
data.groupby(data.index.time).mean().plot();

# %%
pivoted = data.pivot_table('Total', index=data.index.time, columns=data.index.date)
pivoted.iloc[:5, :5]
# Out:
#           2012-10-03  2012-10-04  2012-10-05  2012-10-06  2012-10-07
# 00:00:00        13.0        18.0        11.0        15.0        11.0
# 01:00:00        10.0         3.0         8.0        15.0        17.0
# 02:00:00         2.0         9.0         7.0         9.0         3.0
# 03:00:00         5.0         3.0         4.0         3.0         6.0
# 04:00:00         7.0         8.0         9.0         5.0         3.0

# %%
pivoted.plot(legend=False, alpha=0.01);

# %% [markdown]
# The two peaks that go up during the morning and the evening may show the weekdays and the faint broader lines may show the weekend communtes
